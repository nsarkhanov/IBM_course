# %%
from matplotlib.backends.backend_agg import  FigureCanvasAgg as FigureCanvas
from matplotlib.figure  import Figure
import numpy as np

# %%
fig=Figure()
canvas=FigureCanvas(fig)

# %%
x=np.random.randn(10000)
ax=fig.add_subplot(111)
ax.hist(x,10)    # number show that how many  column stake in x  to show the number 
ax.set_title("Normal Distribution $\mu=0, \sigma=1$")
fig.savefig("2")

# %% [markdown]
# Plot function

# %%
import matplotlib.pyplot as plt
plt.plot(5,5,'o')
plt.show
plt.xlabel("x")
plt.ylabel("y")
plt.title("ploting examle")
# Out:
# Text(0.5, 1.0, 'ploting examle')

# %%
# !pip3 install pandas
import pandas as pd
index=[1980,1981,1982,1983,1984]
data={"India":[8880,8670,8147,7338,5704],"China":[5123,6682,3308,1863,1527]}

# %%
india_china_df=pd.DataFrame(data,index)

# %%
india_china_df.plot()
# Out:
# <AxesSubplot:>
